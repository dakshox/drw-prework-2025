# %% [markdown]
# # Solution 3.3 - Equity Returns
#
# ## DRW & UofC Quant Foundations
# ### Summer 2025
# #### Mark Hendricks
# #### hendricks@uchicago.edu

# %% [markdown]
# ***

# %% [markdown]
# # 1. Calculating Returns

# %% [markdown]
# Use the data in `data/equity_data.xlsx`
# * tab `prices AAPL`: columns `Unadjusted Price` and `Adjusted Price`
# * tab  `dividends AAPL`: columns `ex_date` and `dividend_amount`
#
# ### 1.1
# For the most recent 2 dividend dates, calculate the one-day return to AAPL using the unadjusted price and the dividend amount.
#
# That is, for a given dividend, calculate the return for the day prior to the "ex date" and ending on the "ex date". Do this for at least the most recent two dividends. (Though it is probably just as easy to adjust the return on every dividend date.)
#
# How close is this to the return calculated from the adjusted price percentage change?
#
# ### 1.2
# For the most recent stock split, (see multiple in `dividend_amount` and indicated in the column `dividend_type`,) calculate the return to AAPL using the unadjusted price along with this split and dividend info.
#
# How close is this computed return to that calculated from the adjusted price growth?

# %% [markdown]
# ***

# %% [markdown]
# # 2. Stock Sensitivity
#
# Use the data in `data/equity_data.xlsx`, in the tab `etf history`.
#
# For the ETFs listed in `etf history`, calculate their percentage change over time. (These are adjusted prices, so this is a measure of their returns.)
#
# ## 2.1
# Report the correlation table.
#
# ## 2.2
#
# In equities, there is an important metric: a stock's **beta**:
#
# $$r_t = \alpha + \beta r^{\text{SPY}}_t + \epsilon_t$$
#
# This beta is analyzed with respect to many factors, but it is most widely analyzed with respect to the S&P 500 (or a similar, broad equity index. Thus the notation $r^{\text{SPY}}_t$ on the right-hand side.
#
# ### Calculation
# For each ETF return series, estimate the regression above. (You will estimate many regressions, in a loop, each using SPY as the right-hand-side factor.)
#
# Report these betas. Which ETF has the most overall stock-market risk?
#
# #### Hint:
#
# To estimate the regression, consider using the following approach:
#
# `from sklearn.linear_model import LinearRegression`
#
# `LinearRegression().fit(X,y).coef_`

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:red">Solutions</span>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

import datetime
import warnings

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,6)
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 13

from matplotlib.ticker import (MultipleLocator,
                               FormatStrFormatter,
                               AutoMinorLocator)
import sys
sys.path.insert(0, '../cmds')
from portfolio import *

# %% [markdown]
# ## <span style="color:red">Solution 1</span>

# %%
LOADFILE = '../data/equity_data.xlsx'
TICK = 'AAPL'
TAB = f'prices {TICK}'
px = pd.read_excel(LOADFILE,sheet_name=TAB).set_index('date')

TAB = f'dividends {TICK}'
dvds = pd.read_excel(LOADFILE,sheet_name=TAB).set_index('ex_date')
dvds
# Out:
#            record_date declared_date payable_date  dividend_amount  \
# ex_date
# 2025-05-12  2025-05-12    2025-05-01   2025-05-15         0.260000
# 2025-02-10  2025-02-10    2025-01-30   2025-02-13         0.250000
# 2024-11-08  2024-11-11    2024-10-31   2024-11-14         0.250000
# 2024-08-12  2024-08-12    2024-08-01   2024-08-15         0.250000
# 2024-05-10  2024-05-13    2024-05-02   2024-05-16         0.250000
# ...                ...           ...          ...              ...
# 1988-02-12  1988-02-19    1988-01-28   1988-03-15         0.000714
# 1987-11-17  1987-11-23    1987-11-12   1987-12-15         0.000714
# 1987-08-10  1987-08-14    1987-07-31   1987-09-15         0.000536
# 1987-06-16  1987-05-15    1987-04-22   1987-06-15         2.000000
# 1987-05-11  1987-05-15    1987-04-22   1987-06-15         0.000536
#
#            dividend_frequency dividend_type
# ex_date
# 2025-05-12            Quarter  Regular Cash
# 2025-02-10            Quarter  Regular Cash
# 2024-11-08            Quarter  Regular Cash
# 2024-08-12            Quarter  Regular Cash
# 2024-05-10            Quarter  Regular Cash
# ...                       ...           ...
# 1988-02-12            Quarter  Regular Cash
# 1987-11-17            Quarter  Regular Cash
# 1987-08-10            Quarter  Regular Cash
# 1987-06-16                NaN   Stock Split
# 1987-05-11            Quarter  Regular Cash
#
# [93 rows x 6 columns]

# %% [markdown]
# ### 1.1
#
# With the adjustments, returns are identical up to 4 decimal places.

# %%
rets = px.pct_change()
rets['Unadjusted Price Modified'] = rets.copy()['Unadjusted Price']

for dt in dvds.index:
    if dt in rets.index:
        if dvds.loc[dt,'dividend_type']=='Regular Cash':
            rets.loc[dt,'Unadjusted Price Modified'] = (px.loc[dt,'Unadjusted Price'] + dvds.loc[dt,'dividend_amount']) / px['Unadjusted Price'].shift().loc[dt] - 1

        elif dvds.loc[dt,'dividend_type']=='Stock Split':
            rets.loc[dt,'Unadjusted Price Modified'] = dvds.loc[dt,'dividend_amount'] * px.loc[dt,'Unadjusted Price'] / px['Unadjusted Price'].shift().loc[dt] - 1

# %%
rets.loc[dvds.index[0:4],:].style.format('{:.4%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_68ede">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68ede_level0_col0" class="col_heading level0 col0" >Adjusted Price</th>
#       <th id="T_68ede_level0_col1" class="col_heading level0 col1" >Unadjusted Price</th>
#       <th id="T_68ede_level0_col2" class="col_heading level0 col2" >Unadjusted Price Modified</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ex_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68ede_level0_row0" class="row_heading level0 row0" >2025-05-12 00:00:00</th>
#       <td id="T_68ede_row0_col0" class="data row0 col0" >6.3147%</td>
#       <td id="T_68ede_row0_col1" class="data row0 col1" >6.1754%</td>
#       <td id="T_68ede_row0_col2" class="data row0 col2" >6.3064%</td>
#     </tr>
#     <tr>
#       <th id="T_68ede_level0_row1" class="row_heading level0 row1" >2025-02-10 00:00:00</th>
#       <td id="T_68ede_row1_col0" class="data row1 col0" >0.1187%</td>
#       <td id="T_68ede_row1_col1" class="data row1 col1" >0.0088%</td>
#       <td id="T_68ede_row1_col2" class="data row1 col2" >0.1186%</td>
#     </tr>
#     <tr>
#       <th id="T_68ede_level0_row2" class="row_heading level0 row2" >2024-11-08 00:00:00</th>
#       <td id="T_68ede_row2_col0" class="data row2 col0" >-0.1188%</td>
#       <td id="T_68ede_row2_col1" class="data row2 col1" >-0.2286%</td>
#       <td id="T_68ede_row2_col2" class="data row2 col2" >-0.1187%</td>
#     </tr>
#     <tr>
#       <th id="T_68ede_level0_row3" class="row_heading level0 row3" >2024-08-12 00:00:00</th>
#       <td id="T_68ede_row3_col0" class="data row3 col0" >0.7130%</td>
#       <td id="T_68ede_row3_col1" class="data row3 col1" >0.5966%</td>
#       <td id="T_68ede_row3_col2" class="data row3 col2" >0.7122%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 1.2
#
# By adjusting for the split, we get almost the exact same return as the "Adjusted Price" series.
#
# Note that the "Unadjusted Price" would show a loss of nearly 75%!

# %%
rets.loc[dvds[dvds['dividend_type']=='Stock Split'].index[0]].to_frame().style.format('{:.4%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ae2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ae2e_level0_col0" class="col_heading level0 col0" >2020-08-31 00:00:00</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ae2e_level0_row0" class="row_heading level0 row0" >Adjusted Price</th>
#       <td id="T_6ae2e_row0_col0" class="data row0 col0" >3.3912%</td>
#     </tr>
#     <tr>
#       <th id="T_6ae2e_level0_row1" class="row_heading level0 row1" >Unadjusted Price</th>
#       <td id="T_6ae2e_row1_col0" class="data row1 col0" >-74.1522%</td>
#     </tr>
#     <tr>
#       <th id="T_6ae2e_level0_row2" class="row_heading level0 row2" >Unadjusted Price Modified</th>
#       <td id="T_6ae2e_row2_col0" class="data row2 col0" >3.3912%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Extra Analysis
#
# #### Correlation
#
# The unadjusted price series return has relatively low correlation with the adjusted series.
#
# However, after the modifications made above, it is over 99% correlated.

# %%
rets.corr().style.format('{:.1%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_525b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_525b6_level0_col0" class="col_heading level0 col0" >Adjusted Price</th>
#       <th id="T_525b6_level0_col1" class="col_heading level0 col1" >Unadjusted Price</th>
#       <th id="T_525b6_level0_col2" class="col_heading level0 col2" >Unadjusted Price Modified</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_525b6_level0_row0" class="row_heading level0 row0" >Adjusted Price</th>
#       <td id="T_525b6_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_525b6_row0_col1" class="data row0 col1" >76.1%</td>
#       <td id="T_525b6_row0_col2" class="data row0 col2" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_525b6_level0_row1" class="row_heading level0 row1" >Unadjusted Price</th>
#       <td id="T_525b6_row1_col0" class="data row1 col0" >76.1%</td>
#       <td id="T_525b6_row1_col1" class="data row1 col1" >100.0%</td>
#       <td id="T_525b6_row1_col2" class="data row1 col2" >76.2%</td>
#     </tr>
#     <tr>
#       <th id="T_525b6_level0_row2" class="row_heading level0 row2" >Unadjusted Price Modified</th>
#       <td id="T_525b6_row2_col0" class="data row2 col0" >100.0%</td>
#       <td id="T_525b6_row2_col1" class="data row2 col1" >76.2%</td>
#       <td id="T_525b6_row2_col2" class="data row2 col2" >100.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Performance
#
# Without the adjustment, the stock splits and unaccounted dividends lead to a much lower mean and higher volatility.

# %%
performanceMetrics(rets,annualization=252).style.format('{:.1%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_cbc67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbc67_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_cbc67_level0_col1" class="col_heading level0 col1" >Vol</th>
#       <th id="T_cbc67_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_cbc67_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_cbc67_level0_col4" class="col_heading level0 col4" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbc67_level0_row0" class="row_heading level0 row0" >Adjusted Price</th>
#       <td id="T_cbc67_row0_col0" class="data row0 col0" >35.6%</td>
#       <td id="T_cbc67_row0_col1" class="data row0 col1" >32.9%</td>
#       <td id="T_cbc67_row0_col2" class="data row0 col2" >108.2%</td>
#       <td id="T_cbc67_row0_col3" class="data row0 col3" >-17.9%</td>
#       <td id="T_cbc67_row0_col4" class="data row0 col4" >15.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cbc67_level0_row1" class="row_heading level0 row1" >Unadjusted Price</th>
#       <td id="T_cbc67_row1_col0" class="data row1 col0" >24.7%</td>
#       <td id="T_cbc67_row1_col1" class="data row1 col1" >42.4%</td>
#       <td id="T_cbc67_row1_col2" class="data row1 col2" >58.2%</td>
#       <td id="T_cbc67_row1_col3" class="data row1 col3" >-85.5%</td>
#       <td id="T_cbc67_row1_col4" class="data row1 col4" >15.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cbc67_level0_row2" class="row_heading level0 row2" >Unadjusted Price Modified</th>
#       <td id="T_cbc67_row2_col0" class="data row2 col0" >35.0%</td>
#       <td id="T_cbc67_row2_col1" class="data row2 col1" >32.9%</td>
#       <td id="T_cbc67_row2_col2" class="data row2 col2" >106.5%</td>
#       <td id="T_cbc67_row2_col3" class="data row2 col3" >-17.9%</td>
#       <td id="T_cbc67_row2_col4" class="data row2 col4" >15.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:red">Solution 2</span>

# %%
LOADFILE = '../data/equity_data.xlsx'
TAB = 'etf history'
etfs = pd.read_excel(LOADFILE,sheet_name=TAB).set_index('date')
spy = etfs[['SPY']]

# %% [markdown]
# ## <span style="color:red">2.1</span>

# %%
rets = etfs.pct_change(fill_method=None)
rets.corr().style.format('{:.1%}').background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ea3ba_row0_col0, #T_ea3ba_row0_col1, #T_ea3ba_row1_col0, #T_ea3ba_row1_col1, #T_ea3ba_row2_col2, #T_ea3ba_row3_col3, #T_ea3ba_row4_col4, #T_ea3ba_row5_col5, #T_ea3ba_row6_col6, #T_ea3ba_row7_col7, #T_ea3ba_row8_col8, #T_ea3ba_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ea3ba_row0_col2, #T_ea3ba_row2_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_ea3ba_row0_col3 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_ea3ba_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_ea3ba_row0_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ea3ba_row0_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ea3ba_row0_col7 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ea3ba_row0_col8, #T_ea3ba_row8_col0, #T_ea3ba_row8_col1, #T_ea3ba_row8_col2, #T_ea3ba_row8_col3, #T_ea3ba_row8_col4, #T_ea3ba_row8_col5, #T_ea3ba_row8_col6, #T_ea3ba_row8_col7, #T_ea3ba_row8_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ea3ba_row0_col9, #T_ea3ba_row1_col6, #T_ea3ba_row1_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ea3ba_row1_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_ea3ba_row1_col3, #T_ea3ba_row2_col3, #T_ea3ba_row3_col1 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_ea3ba_row1_col4, #T_ea3ba_row5_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_ea3ba_row1_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_ea3ba_row1_col7, #T_ea3ba_row4_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_ea3ba_row1_col8, #T_ea3ba_row3_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ea3ba_row2_col1 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_ea3ba_row2_col4 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_ea3ba_row2_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_ea3ba_row2_col6, #T_ea3ba_row9_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_ea3ba_row2_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ea3ba_row2_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ea3ba_row2_col9, #T_ea3ba_row3_col9, #T_ea3ba_row9_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ea3ba_row3_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_ea3ba_row3_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_ea3ba_row3_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_ea3ba_row3_col5 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_ea3ba_row3_col6 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_ea3ba_row3_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_ea3ba_row4_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_ea3ba_row4_col2 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_ea3ba_row4_col3, #T_ea3ba_row5_col1, #T_ea3ba_row7_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_ea3ba_row4_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_ea3ba_row4_col6, #T_ea3ba_row6_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ea3ba_row4_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_ea3ba_row4_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ea3ba_row4_col9, #T_ea3ba_row5_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ea3ba_row5_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_ea3ba_row5_col3 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_ea3ba_row5_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_ea3ba_row5_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ea3ba_row5_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ea3ba_row5_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ea3ba_row6_col0, #T_ea3ba_row9_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ea3ba_row6_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ea3ba_row6_col2, #T_ea3ba_row6_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ea3ba_row6_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ea3ba_row6_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ea3ba_row6_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ea3ba_row6_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ea3ba_row7_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_ea3ba_row7_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_ea3ba_row7_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_ea3ba_row7_col4 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ea3ba_row7_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_ea3ba_row7_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ea3ba_row7_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ea3ba_row7_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ea3ba_row9_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_ea3ba_row9_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_ea3ba_row9_col4, #T_ea3ba_row9_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ea3ba_row9_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ea3ba_row9_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ea3ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea3ba_level0_col0" class="col_heading level0 col0" >SPY</th>
#       <th id="T_ea3ba_level0_col1" class="col_heading level0 col1" >UPRO</th>
#       <th id="T_ea3ba_level0_col2" class="col_heading level0 col2" >EEM</th>
#       <th id="T_ea3ba_level0_col3" class="col_heading level0 col3" >VGK</th>
#       <th id="T_ea3ba_level0_col4" class="col_heading level0 col4" >EWJ</th>
#       <th id="T_ea3ba_level0_col5" class="col_heading level0 col5" >IYR</th>
#       <th id="T_ea3ba_level0_col6" class="col_heading level0 col6" >DBC</th>
#       <th id="T_ea3ba_level0_col7" class="col_heading level0 col7" >HYG</th>
#       <th id="T_ea3ba_level0_col8" class="col_heading level0 col8" >TIP</th>
#       <th id="T_ea3ba_level0_col9" class="col_heading level0 col9" >BITO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea3ba_level0_row0" class="row_heading level0 row0" >SPY</th>
#       <td id="T_ea3ba_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_ea3ba_row0_col1" class="data row0 col1" >99.8%</td>
#       <td id="T_ea3ba_row0_col2" class="data row0 col2" >81.3%</td>
#       <td id="T_ea3ba_row0_col3" class="data row0 col3" >85.8%</td>
#       <td id="T_ea3ba_row0_col4" class="data row0 col4" >64.6%</td>
#       <td id="T_ea3ba_row0_col5" class="data row0 col5" >71.1%</td>
#       <td id="T_ea3ba_row0_col6" class="data row0 col6" >41.0%</td>
#       <td id="T_ea3ba_row0_col7" class="data row0 col7" >68.2%</td>
#       <td id="T_ea3ba_row0_col8" class="data row0 col8" >-10.2%</td>
#       <td id="T_ea3ba_row0_col9" class="data row0 col9" >42.6%</td>
#     </tr>
#     <tr>
#       <th id="T_ea3ba_level0_row1" class="row_heading level0 row1" >UPRO</th>
#       <td id="T_ea3ba_row1_col0" class="data row1 col0" >99.8%</td>
#       <td id="T_ea3ba_row1_col1" class="data row1 col1" >100.0%</td>
#       <td id="T_ea3ba_row1_col2" class="data row1 col2" >78.5%</td>
#       <td id="T_ea3ba_row1_col3" class="data row1 col3" >83.2%</td>
#       <td id="T_ea3ba_row1_col4" class="data row1 col4" >72.6%</td>
#       <td id="T_ea3ba_row1_col5" class="data row1 col5" >76.0%</td>
#       <td id="T_ea3ba_row1_col6" class="data row1 col6" >41.4%</td>
#       <td id="T_ea3ba_row1_col7" class="data row1 col7" >76.0%</td>
#       <td id="T_ea3ba_row1_col8" class="data row1 col8" >-6.4%</td>
#       <td id="T_ea3ba_row1_col9" class="data row1 col9" >42.8%</td>
#     </tr>
#     <tr>
#       <th id="T_ea3ba_level0_row2" class="row_heading level0 row2" >EEM</th>
#       <td id="T_ea3ba_row2_col0" class="data row2 col0" >81.3%</td>
#       <td id="T_ea3ba_row2_col1" class="data row2 col1" >78.5%</td>
#       <td id="T_ea3ba_row2_col2" class="data row2 col2" >100.0%</td>
#       <td id="T_ea3ba_row2_col3" class="data row2 col3" >83.3%</td>
#       <td id="T_ea3ba_row2_col4" class="data row2 col4" >73.6%</t

# %% [markdown]
# ## <span style="color:red">2.2</span>

# %%
x = spy.pct_change(fill_method=None).dropna()

betas = pd.DataFrame(index=etfs.columns,dtype=float, columns=['SPY beta'])
for col in etfs.columns:
    y = etfs[[col]].pct_change(fill_method=None).dropna()
    y, x = y.align(x,join='inner',axis=0)
    betas.loc[col] = LinearRegression().fit(x,y).coef_

betas.T.style.format('{:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_74b2a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74b2a_level0_col0" class="col_heading level0 col0" >SPY</th>
#       <th id="T_74b2a_level0_col1" class="col_heading level0 col1" >UPRO</th>
#       <th id="T_74b2a_level0_col2" class="col_heading level0 col2" >EEM</th>
#       <th id="T_74b2a_level0_col3" class="col_heading level0 col3" >VGK</th>
#       <th id="T_74b2a_level0_col4" class="col_heading level0 col4" >EWJ</th>
#       <th id="T_74b2a_level0_col5" class="col_heading level0 col5" >IYR</th>
#       <th id="T_74b2a_level0_col6" class="col_heading level0 col6" >DBC</th>
#       <th id="T_74b2a_level0_col7" class="col_heading level0 col7" >HYG</th>
#       <th id="T_74b2a_level0_col8" class="col_heading level0 col8" >TIP</th>
#       <th id="T_74b2a_level0_col9" class="col_heading level0 col9" >BITO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74b2a_level0_row0" class="row_heading level0 row0" >SPY beta</th>
#       <td id="T_74b2a_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_74b2a_row0_col1" class="data row0 col1" >2.99</td>
#       <td id="T_74b2a_row0_col2" class="data row0 col2" >0.98</td>
#       <td id="T_74b2a_row0_col3" class="data row0 col3" >1.01</td>
#       <td id="T_74b2a_row0_col4" class="data row0 col4" >0.74</td>
#       <td id="T_74b2a_row0_col5" class="data row0 col5" >0.91</td>
#       <td id="T_74b2a_row0_col6" class="data row0 col6" >0.42</td>
#       <td id="T_74b2a_row0_col7" class="data row0 col7" >0.38</td>
#       <td id="T_74b2a_row0_col8" class="data row0 col8" >-0.02</td>
#       <td id="T_74b2a_row0_col9" class="data row0 col9" >1.32</td>
#     </tr>
#   </tbody>
# </table>
